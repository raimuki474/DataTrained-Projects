# %%
## Importing required Libraries for working on the dataset

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
world_happiness_data = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv')
world_happiness_data
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
world_happiness_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
world_happiness_data.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
world_happiness_data.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
world_happiness_data1 = world_happiness_data[['Happiness Score', 'Economy (GDP per Capita)', 'Family',
       'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)','Generosity']]
world_happiness_data1.head()
# Out:
#    Happiness Score  Economy (GDP per Capita)   Family  \
# 0            7.587                   1.39651  1.34951
# 1            7.561                   1.30232  1.40223
# 2            7.527                   1.32548  1.36058
# 3            7.522                   1.45900  1.33095
# 4            7.427                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity
# 0     0.29678
# 1     0.43630
# 2     0.34139
# 3     0.34699
# 4     0.45811

# %%
plt.figure(figsize = (8, 8))
sns.heatmap(world_happiness_data1.corr(), annot = True, cmap = 'coolwarm')

# %%
variable_pairplot = world_happiness_data1.dropna()
sns.pairplot(variable_pairplot, height = 2)

# %% [markdown]
# <p><strong><h4><u>OBSERVATIONS</u> :</h4></strong></p>
# <ul>
#     <li> From the above heatmap,following factors contribute to happiness score: </li>
#     <ol><li>Economy (GDP per Capita)</li>
#         <li>Family</li>
#         <li>Health (Life Expectancy) </li> </ol>
#     <li>Increase in Economy (GDP per Capita) has strong positive effect on Health (Life Expentancy) and vice-versa. </li>
#     <li> There is no significance correlation between Economy and Generosity </li>
#     <li> There is no strong negative correlation between any of the parameters </li>
#     </ul>

# %%
world_happiness_data.nlargest(5, ['Happiness Score'])
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %% [markdown]
# <p><strong><h4><u>OBSERVATIONS</u> :</h4></strong></p>
#     The country with top Happiness Score are :
#         <ol>
#         <li>Switzerland</li>
#         <li>Iceland</li>
#         <li>Denmark</li>
#         <li>Norway</li>
#         <li>Canada</li></ol>

# %%
world_happiness_data.nlargest(5, ['Health (Life Expectancy)'])
# Out:
#         Country             Region  Happiness Rank  Happiness Score  \
# 23    Singapore  Southeastern Asia              24            6.798
# 71    Hong Kong       Eastern Asia              72            5.474
# 45        Japan       Eastern Asia              46            5.987
# 46  South Korea       Eastern Asia              47            5.984
# 35        Spain     Western Europe              36            6.329
#
#     Standard Error  Economy (GDP per Capita)   Family  \
# 23         0.03780                   1.52186  1.02000
# 71         0.05051                   1.38604  1.05818
# 45         0.03581                   1.27074  1.25712
# 46         0.04098                   1.24461  0.95774
# 35         0.03468                   1.23011  1.31379
#
#     Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 23                   1.02525  0.54252                        0.49210
# 71                   1.01328  0.59608                        0.37124
# ...

# %% [markdown]
# <p><strong><h4><u>OBSERVATIONS</u> :</h4></strong></p>
#     The country with highest Health (Life Expectancy) are :
#         <ol>
#         <li>Singapore</li>
#         <li>HongKong</li>
#         <li>Japan</li>
#         <li>South Korea</li>
#         <li>Spain</li></ol>

# %%
world_happiness_data.nlargest(5, ['Family'])
# Out:
#         Country                      Region  Happiness Rank  Happiness Score  \
# 1       Iceland              Western Europe               2            7.561
# 17      Ireland              Western Europe              18            6.940
# 2       Denmark              Western Europe               3            7.527
# 0   Switzerland              Western Europe               1            7.587
# 43   Uzbekistan  Central and Eastern Europe              44            6.003
#
#     Standard Error  Economy (GDP per Capita)   Family  \
# 1          0.04884                   1.30232  1.40223
# 17         0.03676                   1.33596  1.36948
# 2          0.03328                   1.32548  1.36058
# 0          0.03411                   1.39651  1.34951
# 43         0.04361                   0.63244  1.34043
#
#     Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 1                    0.94784  0.62877                        0.14145
# ...

# %% [markdown]
# <p><strong><h4><u>OBSERVATIONS</u> :</h4></strong></p>
#     The country with highest Family members are :
#         <ol>
#         <li>Iceland</li>
#         <li>Ireland</li>
#         <li>Denmark</li>
#         <li>Switzerland</li>
#         <li>Uzbekistan</li></ol>
